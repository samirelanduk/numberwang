# %%
import sys; sys.path.append("..")
import numerus.learning as learning
import numpy as np
import pandas as pd
from IPython.display import display

# %% [markdown]
# Get the Iris dataset, which looks at three different kind of flower, and four measurements of them. I only want two measurements, for two different kinds.

# %%
# Get the data
data = pd.read_csv("../tests/data/iris.csv")
data = data.loc[:, ["Sepal length", "Petal length", "Class"]]
data = data[data.Class != "Iris-virginica"]
learning.display_dataset(data, title="All data")

# %%
# Split into training and test data
training_data, test_data = learning.divide_data(data)
learning.display_dataset(training_data, title="Training data")

# %%
# Create model
model = learning.Perceptron(training_data=training_data)
print(model)
model.display()
